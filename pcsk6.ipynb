# %%
import pandas as pd
import numpy as np
import scanpy as sc

# %%
adata = sc.read('./ncom_2021.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 620649 × 68794
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.01', 'seurat_clusters', 'population', 'dataset', 'nCount_HTO', 'nFeature_HTO', 'SCT_snn_res.0.05', 'SCT_snn_res.0.02', 'Diagnosis', 'Status', 'Sample_Name', 'Age', 'Ethnicity', 'Smoking_status', 'Diagnosis2', 'dataset2'
#     var: 'features'

# %%
sc.pl.dotplot(adata, 'SFTPC', groupby='dataset')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 sc.pl.dotplot(adata, 'SFTPC', groupby='dataset')
#
# File ~/opt/miniconda3/envs/ipf/lib/python3.9/site-packages/scanpy/plotting/_dotplot.py:942, in dotplot(adata, var_names, groupby, use_raw, log, num_categories, expression_cutoff, mean_only_expressed, cmap, dot_max, dot_min, standard_scale, smallest_dot, title, colorbar_title, size_title, figsize, dendrogram, gene_symbols, var_group_positions, var_group_labels, var_group_rotation, layer, swap_axes, dot_color_df, show, save, ax, return_fig, vmin, vmax, vcenter, norm, **kwds)
#     939 if 'color_map' in kwds:
#     940     del kwds['color_map']
# --> 942 dp = DotPlot(
#     943     adata,
#     944     var_names,
#     945     groupby,
#     946     use_raw=use_raw,
#     947     log=log,
#     948     num_categories=num_categories,
# ...

# %%
vumc = adata[adata.obs['dataset'].isin([ ])]
yale = adata[adata.obs['dataset'].isin([ ])]
